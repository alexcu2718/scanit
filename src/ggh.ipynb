# %%
PARSE_STR="""
Trial 1 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.48s user 4.23s system 202% cpu 3.798 total
Trial 2 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.41s user 2.65s system 276% cpu 2.193 total
Trial 3 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.39s user 2.70s system 274% cpu 2.220 total
Trial 4 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.31s user 2.78s system 274% cpu 2.221 total
Trial 5 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.35s user 2.73s system 274% cpu 2.219 total
Trial 6 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.33s user 2.77s system 274% cpu 2.223 total
Trial 7 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.38s user 2.72s system 275% cpu 2.216 total
Trial 8 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.36s user 2.77s system 273% cpu 2.237 total
Trial 9 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.34s user 2.79s system 274% cpu 2.233 total
Trial 10 for scanit
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
scanit zshrc -H  3.31s user 2.82s system 271% cpu 2.260 total
Trial 1 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.86s user 2.35s system 417% cpu 1.007 total
Trial 2 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.79s user 2.44s system 418% cpu 1.009 total
Trial 3 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.98s user 2.31s system 399% cpu 1.074 total
Trial 4 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.79s user 2.42s system 416% cpu 1.012 total
Trial 5 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  2.04s user 2.17s system 414% cpu 1.017 total
Trial 6 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.87s user 2.36s system 418% cpu 1.010 total
Trial 7 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.86s user 2.38s system 416% cpu 1.018 total
Trial 8 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.93s user 2.32s system 418% cpu 1.015 total
Trial 9 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.95s user 2.30s system 413% cpu 1.027 total
Trial 10 for scanf
/tmp/alexc-code-zsh/.zshrc
/home/alexc/.zshrc
/home/alexc/zshrctest
/home/alexc/.zshrc.save
/home/alexc/.oh-my-zsh/templates/minimal.zshrc
/home/alexc/.oh-my-zsh/templates/zshrc.zsh-template
/home/alexc/.local/share/Trash/files/.zshrc
/home/alexc/.local/share/Trash/info/.zshrc.trashinfo
/home/alexc/.zshrctest
/home/alexc/.zshrc.pre-oh-my-zsh
/home/alexc/.zshrc.pre-oh-my-zsh-2024-12-14_19-27-40
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143626
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241222143057
/home/alexc/ZSHRCBACKUPS/.zshrcbackup_20241221115632
/usr/share/kdevplatform/shellutils/.zshrc
./scanf zshrc -H  1.87s user 2.39s system 412% cpu 1.032 total
"""

# %%
myty=list(filter(
lambda x: 'alexc' not in x  and 'share' not in x and  'Trial' not in x and len(x)>2,PARSE_STR.split('\n')))




myty=list(map(lambda x:x.split('-H')[0].replace('zshrc','')+ x.split('cpu ')[-1].replace(' total',''),myty))

scanit=list(map(lambda x:float(x.replace('scanit',' ').strip()),(filter(lambda x:'scanit' in x,myty))))

print(sum(scanit)/len(scanit))


scanf=list(map(lambda x:float(x.replace('./scanf',' ').strip()),(filter(lambda x:'./scanf' in x,myty))))
print(sum(scanf)/len(scanf))
# Out:
# 2.382
# 1.0221

# %% [markdown]
# for i in {1..10}; do echo "Trial $i for scanit"; time scanit zshrc ;done
# for i in {1..10}; do echo "Trial $i for scanf"; time ./scanf zshrc ; done
